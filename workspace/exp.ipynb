# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv("/Users/diwanshuyadav/Documents/Metafusion_NLP/dataset_gen/dataset_gemini_v2.csv")

# %%
from shared.workspace.data_v3.data_utils.utils import (
    modify_dataframe as modify_dataframe_v3
)

# %%
df2["additional_info"]="na"

# %%
df2['schema']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3655    NaN
# 3656    NaN
# 3657    NaN
# 3658    NaN
# 3659    NaN
# Name: schema, Length: 3660, dtype: object

# %%
mod_df= modify_dataframe_v3(df2)
# Out:
# 2025-06-22 22:28:24.407 | INFO     | shared.workspace.data_v3.data_utils.utils:modify_dataframe:128 - Modifying DataFrame...
# 2025-06-22 22:28:24.408 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:129 - input DataFrame length: 3660
# Modifying Queries: 100%|██████████| 3660/3660 [00:00<00:00, 325387.95it/s]
# 2025-06-22 22:28:24.583 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:135 - Modified queries length: 0
# Testing Line-based Parsing: 0it [00:00, ?it/s]
# 2025-06-22 22:28:24.583 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:137 - Line-based queries length: 0
# Converting Schemas to Line-based Format: 0it [00:00, ?it/s]
# 2025-06-22 22:28:24.584 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:139 - Modified schemas length: 0

# %%
mod_df
# Out:
# []

# %%
df = pd.read_csv("shared/workspace/data_v3/data_v1.csv")

# %%
df.iloc[0]
# Out:
# schema                    {"collections": [{"name": "event", "document":...
# mongo_query                   db.event.find({"severity_level": {"$gt": 3}})
# natural_language_query       Find alerts with severity level greater than 3
# additional_info                                                          na
# Name: 0, dtype: object

# %%
mdf = modify_dataframe_v3(df)
# Out:
# 2025-06-22 21:59:12.925 | INFO     | shared.workspace.data_v3.data_utils.utils:modify_dataframe:128 - Modifying DataFrame...
# 2025-06-22 21:59:12.926 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:129 - input DataFrame length: 1992
# Modifying Queries: 100%|██████████| 1992/1992 [00:00<00:00, 33744.02it/s]
# 2025-06-22 21:59:13.299 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:135 - Modified queries length: 1964
# Testing Line-based Parsing: 100%|██████████| 1964/1964 [00:00<00:00, 300719.64it/s]
# 2025-06-22 21:59:13.307 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:137 - Line-based queries length: 1964
# Converting Schemas to Line-based Format: 100%|██████████| 1964/1964 [00:00<00:00, 92311.63it/s]
# 2025-06-22 21:59:13.329 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:139 - Modified schemas length: 1964

# %%
mdf[0]
# Out:
# {'mongo_query': 'db.event.find({"severity_level":{"$gt":3}})',
#  'natural_language_query': 'Find alerts with severity level greater than 3',
#  'additional_info': 'na',
#  'modified_query': {'severity_level': {'$gt': 3}, '_original_numbers': {}},
#  'collection_name': 'event',
#  'in2out': {'event_id': 'event_id',
#   'timestamp': 'timestamp',
#   'severity_level': 'severity_level',
#   'camera_id': 'camera_id',
#   'gender': 'person_attributes.gender',
#   'age': 'person_attributes.age',
#   'upper_color': 'person_attributes.upper_color',
#   'lower_color': 'person_attributes.lower_color',
#   'hair_type': 'person_attributes.hair_type',
#   'hair_color': 'person_attributes.hair_color',
#   'body_type': 'person_attributes.body_type',
#   'accessories': 'person_attributes.accessories',
#   'actions': 'person_attributes.actions',
#   'carrying': 'person_attributes.carrying',
#   'footwear': 'person_attributes.footwear',
#   'sleeve_type': 'person_attributes.sleeve_type',
#   'orientation': 'vehicle_attributes.orientation',
#   'brand_name': 'vehicle_attributes.brand_name',
#   'vehicle_color': 'vehicle_attributes.vehicle_color',
#   'vehicle_type': 'vehicle_attributes.vehicle_type',
#   'label': 'vehicle_attributes.label',
#   'vehicle_i_type': 'vehicle_attributes.vehicle_i_type',
#   'special_type': 'vehicle_attributes.special_type',
#   'latitude': 'location.latitude',
#   'longitude': 'location.longitude',
#   'temperature': 'sensor_readings.temperature',
#   'speed': 'sensor_readings.speed',
#   'distance': 'sensor_readings.distance'},
#  'out2in': {'event_id': 'event_id',
#   'timestamp': 'timestamp',
#   'severity_level': 'severity_level',
#   'camera_id': 'camera_id',
#   'person_attributes.gender': 'gender',
#   'person_attributes.age': 'age',
#   'person_attributes.upper_color': 'upper_color',
#   'person_attributes.lower_color': 'lower_color',
#   'person_attributes.hair_type': 'hair_type',
#   'person_attributes.hair_color': 'hair_color',
#   'person_attributes.body_type': 'body_type',
#   'person_attributes.accessories': 'accessories',
#   'person_attributes.actions': 'actions',
#   'person_attributes.carrying': 'carrying',
#   'person_attributes.footwear': 'footwear',
#   'person_attributes.sleeve_type': 'sleeve_type',
#   'vehicle_attributes.orientation': 'orientation',
#   'vehicle_attributes.brand_name': 'brand_name',
#   'vehicle_attributes.vehicle_color': 'vehicle_color',
#   'vehicle_attributes.vehicle_type': 'vehicle_type',
#   'vehicle_attributes.label': 'label',
#   'vehicle_attributes.vehicle_i_type': 'vehicle_i_type',
#   'vehicle_attributes.special_type': 'special_type',
#   'location.latitude': 'latitude',
#   'location.longitude': 'longitude',
#   'sensor_readings.temperature': 'temperature',
#   'sensor_readings.speed': 'speed',
#   'sensor_readings.distance': 'distance'},
#  'schema': {'collections': [{'name': 'event',
#     'document': {'properties': {'event_id': {'bsonType': 'string',
#        'description': 'Unique identifier for the event'},
#       'timestamp': {'bsonType': 'date',
#        'description': 'Date and time of the event'},
#       'severity_level': {'bsonType': 'int',
#        'description': 'Severity level of the event (1-5)'},
#       'camera_id': {'bsonType': 'string',
#        'description': 'Identifier of the camera that recorded the event'},
#       'person_attributes': {'bsonType': 'object',
#        'properties': {'gender': {'bsonType': 'string',
#          'description': 'Gender of the person'},
#         'age': {'bsonType': 'int', 'description': 'Age of the person'},
#         'upper_color': {'bsonType': 'string',
#          'description': "Color of the person's upper clothing"},
#         'lower_color': {'bsonType': 'string',
#          'description': "Color of the person's lower clothing"},
#         'hair_type': {'bsonType': 'string',
#          'description': 'Type of hair (e.g. curly, straight)'},
#         'hair_color': {'bsonType': 'string',
#          'description': "Color of the person's hair"},
#         'body_type': {'bsonType': 'string',
#          'description': 'Body type of the person'},
#         'accessories': {'bsonType': 'array',
#          'description': 'List of accessories the person is carrying'},
#         'actions': {'bsonType': 'array',
#          'description': 'List of actions performed by the person'},
#         'carrying': {'bsonType': 'string',
#          'description': 'What the person is carrying'},
#         'footwear': {'bsonType': 'string',
#          'description': 'Type of footwear the person is wearing'},
#         'sleeve_type': {'bsonType': 'string',
#          'description': "Type of sleeves on the person's clothing"},
#         'orientation': {'bsonType': 'string',
#          'description': 'Orientation of the person (e.g. facing north)'}}},
#       'vehicle_attributes': {'bsonType': 'object',
#        'properties': {'brand_name': {'bsonType': 'string',
#          'description': 'Brand name of the vehicle'},
#         'vehicle_color': {'bsonType': 'string',
#          'description': 'Color of the vehicle'},
#         'vehicle_type': {'bsonType': 'string',
#          'description': 'Type of the vehicle (e.g. car, truck)'},
#         'label': {'bsonType': 'string',
#          'description': 'Label or tag associated with the vehicle'},
#         'vehicle_i_type': {'bsonType': 'string',
#          'description': 'Identifier type of the vehicle'},
#         'special_type': {'bsonType': 'string',
#          'description': 'Special type or modifications of the vehicle'},
#         'orientation': {'bsonType': 'string',
#          'description': 'Orientation of the vehicle'}}},
#       'location': {'bsonType': 'object',
#        'properties': {'latitude': {'bsonType': 'double',
#          'description': 'Latitude of the event location'},
#         'longitude': {'bsonType': 'double',
#          'description': 'Longitude of the event location'}}},
#       'sensor_readings': {'bsonType': 'object',
#        'properties': {'temperature': {'bsonType': 'double',
#          'description': 'Temperature reading during the event'},
#         'speed': {'bsonType': 'double',
#          'description': 'Speed of the vehicle at the time of event'},
#         'distance': {'bsonType': 'double',
#          'description': 'Distance measurement during the event'}}}}}}],
#   'version': 1},
#  'line_based_query': 'severity_level $gt 3',
#  'line_based_schema': "event_id  // Unique identifier for the event (string)\ntimestamp  // Date and time of the event (date)\nseverity_level  // Severity level of the event (1-5) (int)\ncamera_id  // Identifier of the camera that recorded the event (string)\nperson_attributes  // (object)\ngender  // Gender of the person (string)\nage  // Age of the person (int)\nupper_color  // Color of the person's upper clothing (string)\nlower_color  // Color of the person's lower clothing (string)\nhair_type  // Type of hair (e.g. curly, straight) (string)\nhair_color  // Color of the person's hair (string)\nbody_type  // Body type of the person (string)\naccessories  // List of accessories the person is carrying (array)\nactions  // List of actions performed by the person (array)\ncarrying  // What the person is carrying (string)\nfootwear  // Type of footwear the person is wearing (string)\nsleeve_type  // Type of sleeves on the person's clothing (string)\norientation  // Orientation of the person (e.g. facing north) (string)\nvehicle_attributes  // (object)\nbrand_name  // Brand name of the vehicle (string)\nvehicle_color  // Color of the vehicle (string)\nvehicle_type  // Type of the vehicle (e.g. car, truck) (string)\nlabel  // Label or tag associated with the vehicle (string)\nvehicle_i_type  // Identifier type of the vehicle (string)\nspecial_type  // Special type or modifications of the vehicle (string)\norientation  // Orientation of the vehicle (string)\nlocation  // (object)\nlatitude  // Latitude of the event location (double)\nlongitude  // Longitude of the event location (double)\nsensor_readings  // (object)\ntemperature  // Temperature reading during the event (double)\nspeed  // Speed of the vehicle at the time of event (double)\ndistance  // Distance measurement during the event (double)"}

# %%
a="""{"collections": [
    {
      "name": "events",
      "document": {
        "bsonType": "object",
        "properties": {
          "identifier": {
            "bsonType": "object",
            "properties": {
              "camgroup_id": {
                "bsonType": "string",
                "description": "Use this to filter events by group"
              },
              "task_id": {
                "bsonType": "string",
                "description": "Map natural language application names to their corresponding short_name values",
                  "mappings": [
                    {"application_name": "License Plate Recognition", "task_id_value": "ANPR"},
                    {"application_name": "Crowd Estimation", "task_id_value": "CROWD_EST"},
                    {"application_name": "Crowd Count", "task_id_value": "CROWD_COUNT"},
                    {"application_name": "Facial Recognition", "task_id_value": "FR"},
                    {"application_name": "Abandoned Bag Alert", "task_id_value": "ABANDONED_BAG"},
                    {"application_name": "Intruder Alert", "task_id_value": "INTRUDER_DETECT"},
                    {"application_name": "Camera Tampering", "task_id_value": "CAM_TAMPERING"},
                    {"application_name": "Person Slip Detection", "task_id_value": "SLIP_DETECT"},
                    {"application_name": "PPE Violation", "task_id_value": "PPE_VOILATION"},
                    {"application_name": "Wrong Way", "task_id_value": "wrong_way"},
                    {"application_name": "Helmet Violation", "task_id_value": "helmet_violation"},
                    {"application_name": "Triple Riding", "task_id_value": "triple_riding"},
                    {"application_name": "Speed Violation", "task_id_value": "speed_violation"},
                    {"application_name": "Red Light Violation", "task_id_value": "red_light_violation"},
                    {"application_name": "Violence Detection", "task_id_value": "violence_detection"},
                    {"application_name": "Loitering", "task_id_value": "dwell"},
                    {"application_name": "Woman In Isolation", "task_id_value": "wii"},
                    {"application_name": "Woman Hailing Help", "task_id_value": "whh"},
                    {"application_name": "Queue Management", "task_id_value": "qm"},
                    {"application_name": "Tailgating", "task_id_value": "tg"},
                    {"application_name": "Lane violation", "task_id_value": "lane_violation"},
                    {"application_name": "Seat belt", "task_id_value": "seatbelt"},
                    {"application_name": "Parking violation", "task_id_value": "parking_violation"},
                    {"application_name": "Person Attribute", "task_id_value": "pat"},
                    {"application_name": "Vehicle Attribute", "task_id_value": "vat"},
                    {"application_name": "Fire and Smoke Detection", "task_id_value": "fns"},
                    {"application_name": "Parking violation", "task_id_value": "parking_violation"}
                  ]
              },
              "camera_id": {
                "bsonType": "string",
                "description": "Individual camera identifier - use this field to filter events from specific cameras"
              }
            }
          },
          "response": {
            "bsonType": "object",
            "properties": {
              "event": {
                "bsonType": "object",
                "properties": {
                  "severity": {
                    "bsonType": "string",
                    "description": "Can be Low, Medium, Critical"
                  },
                  "blobs": {
                    "bsonType": "array",
                    "items": {
                      "bsonType": "object",
                      "properties": {
                        "url": {
                          "bsonType": "string"
                        },
                        "attribs": {
                          "bsonType": "object",
                          "description": "Attributes for person or vehicle detection",
                          "properties": {
                            "footwear_color": {
                              "bsonType": "string",
                              "enum": ["black", "blue", "brown", "green", "grey", "orange", "pink", "purple", "red", "white", "yellow"],
                              "description": "Color of footwear for person"
                            },
                            "carrying_color": {
                              "bsonType": "string",
                              "enum": ["black", "blue", "brown", "green", "grey", "orange", "pink", "purple", "red", "white", "yellow"],
                              "description": "Color of items being carried"
                            },
                            "lower_color": {
                              "bsonType": "string",
                              "enum": ["black", "blue", "brown", "green", "grey", "orange", "pink", "purple", "red", "white", "yellow"],
                              "description": "Color of lower body clothing"
                            },
                            "upper_color": {
                              "bsonType": "string",
                              "enum": ["black", "blue", "brown", "green", "grey", "orange", "pink", "purple", "red", "white", "yellow"],
                              "description": "Color of upper body clothing"
                            },
                            "gender": {
                              "bsonType": "string",
                              "enum": ["female", "male"],
                              "description": "Gender of the person"
                            },
                            "age": {
                              "bsonType": "string",
                              "enum": ["child", "adult", "older_adult"],
                              "description": "Age category of the person"
                            },
                            "body_type": {
                              "bsonType": "string",
                              "enum": ["fat", "normal", "thin"],
                              "description": "Body type of the person"
                            },
                            "hair_type": {
                              "bsonType": "string",
                              "enum": ["bald_head", "long_hair", "short_hair"],
                              "description": "Hair type of the person"
                            },
                            "hair_color": {
                              "bsonType": "string",
                              "enum": ["black", "blue", "brown", "green", "grey", "orange", "pink", "purple", "red", "white", "yellow"],
                              "description": "Hair color of the person"
                            },
                            "accessories": {
                              "bsonType": "string",
                              "enum": ["glasses", "muffler", "hat", "nothing", "headphone", "hair_band", "kerchief"],
                              "description": "Accessories worn by the person"
                            },
                            "sleeve_type": {
                              "bsonType": "string",
                              "enum": ["short_sleeve", "long_sleeve"],
                              "description": "Type of sleeves on upper clothing"
                            },
                            "orientation": {
                              "bsonType": "string",
                              "enum": ["front", "side", "back"],
                              "description": "Orientation of person or vehicle"
                            },
                            "actions": {
                              "bsonType": "string",
                              "enum": ["calling", "talking", "gathering", "holding", "pushing", "pulling", "carry_arm", "carry_hand"],
                              "description": "Actions being performed by the person"
                            },
                            "upper_type": {
                              "bsonType": "string",
                              "enum": ["stride", "splice", "casual", "formal", "jacket", "logo", "plaid", "thin_stripes", "tshirt", "other", "v_neck", "suit", "thick_stripes", "shirt", "sweater", "vest", "cotton", "suit_up", "tight"],
                              "description": "Type of upper body clothing"
                            },
                            "footwear": {
                              "bsonType": "string",
                              "enum": ["leather", "sport", "boots", "cloth", "casual", "sandals", "stocking", "leather_shoes", "shoes", "sneaker"],
                              "description": "Type of footwear"
                            },
                            "carrying": {
                              "bsonType": "string",
                              "enum": ["hand_bag", "shoulder_bag", "hold_objects_in_front", "backpack", "messenger_bag", "nothing", "plastic_bags", "baby_buggy", "shopping_trolley", "umbrella", "folder", "luggage_case", "suitcase", "box", "plastic_bag", "paper_bag", "hand_trunk", "other"],
                              "description": "Items being carried by the person"
                            },
                            "lower_type": {
                              "bsonType": "string",
                              "enum": ["stripe", "pattern", "long_coat", "trousers", "shorts", "skirt_and_dress", "boots", "long_trousers", "skirt", "short_skirt", "dress", "jeans", "tight_trousers", "capri", "hot_pants", "long_skirt", "plaid", "thin_stripes", "suits", "casual", "formal"],
                              "description": "Type of lower body clothing"
                            },
                            "brand_name": {
                              "bsonType": "string",
                              "enum": ["tvs", "maruti_suzuki", "eicher", "ashok_leyland", "mercedes_benz", "royal_enfield", "chevrolet", "fiat", "jaguar", "audi", "toyota", "sml", "bajaj", "jbm", "bharat_benz", "hero_motor", "volvo", "nissan", "renault", "volkswagen", "mazda", "hero_honda", "hyundai", "mg", "skoda", "land_rover", "yamaha", "kia", "mahindra", "mitsubishi", "ford", "jeep", "tata_motors", "honda", "bmw", "coupe", "force"],
                              "description": "Brand name of the vehicle"
                            },
                            "vehicle_color": {
                              "bsonType": "string",
                              "enum": ["khakhi", "silver", "yellow", "pink", "purple", "green", "blue", "brown", "maroon", "red", "orange", "violet", "white", "black", "grey"],
                              "description": "Color of the vehicle"
                            },
                            "vehicle_i_type": {
                              "bsonType": "string",
                              "enum": ["hmv", "lmv", "lgv", "3_axle", "5_axle", "mcwg", "6_axle", "2_axle", "4_axle", "heavy_vehicle"],
                              "description": "Vehicle classification type"
                            },
                            "vehicle_type": {
                              "bsonType": "string",
                              "enum": ["sedan", "suv", "micro", "hatchback", "wagon", "pick_up", "convertible"],
                              "description": "Type of vehicle"
                            },
                            "special_type": {
                              "bsonType": "string",
                              "enum": ["army_vehicle", "ambulance", "graminseva_4wheeler", "graminseva_3wheeler", "campervan"],
                              "description": "Special vehicle type"
                            }
                          }
                        },
                        "label": {
                          "bsonType": "string",
                          "enum": ["bus", "car", "truck", "motorbike", "bicycle", "e_rikshaw", "cycle_rikshaw", "tractor", "cement_mixer", "mini_truck", "mini_bus", "mini_van", "van"],
                          "description": "Vehicle type what type of vehicle is detected"
                        },
                        "score": {
                          "bsonType": "number",
                          "description": "Confidence score for the detection"
                        },
                        "match_id": {
                          "bsonType": "string",
                          "description": "Match ID for person identification"
                        },
                        "severity": {
                          "bsonType": "string"
                        },
                        "subclass": {
                          "bsonType": "string",
                          "description": "Subclass for the detected object"
                        }
                      }
                    }
                  },
                  "c_timestamp": {
                    "bsonType": "date",
                    "description": "Timestamp of the event"
                  }
                }
              }
            }
          }
        }
      }
    }
  ],
  "version": 1
}
"""

# %%
a
# Out:
# '{"collections": [\n    {\n      "name": "events",\n      "document": {\n        "bsonType": "object",\n        "properties": {\n          "identifier": {\n            "bsonType": "object",\n            "properties": {\n              "camgroup_id": {\n                "bsonType": "string",\n                "description": "Use this to filter events by group"\n              },\n              "task_id": {\n                "bsonType": "string",\n                "description": "Map natural language application names to their corresponding short_name values",\n                  "mappings": [\n                    {"application_name": "License Plate Recognition", "task_id_value": "ANPR"},\n                    {"application_name": "Crowd Estimation", "task_id_value": "CROWD_EST"},\n                    {"application_name": "Crowd Count", "task_id_value": "CROWD_COUNT"},\n                    {"application_name": "Facial Recognition", "task_id_value": "FR"},\n                    {"application_name": "Abandoned Bag Alert", "task_id_value": "ABANDONED_BAG"},\n                    {"application_name": "Intruder Alert", "task_id_value": "INTRUDER_DETECT"},\n                    {"application_name": "Camera Tampering", "task_id_value": "CAM_TAMPERING"},\n                    {"application_name": "Person Slip Detection", "task_id_value": "SLIP_DETECT"},\n                    {"application_name": "PPE Violation", "task_id_value": "PPE_VOILATION"},\n                    {"application_name": "Wrong Way", "task_id_value": "wrong_way"},\n                    {"application_name": "Helmet Violation", "task_id_value": "helmet_violation"},\n                    {"application_name": "Triple Riding", "task_id_value": "triple_riding"},\n                    {"application_name": "Speed Violation", "task_id_value": "speed_violation"},\n                    {"application_name": "Red Light Violation", "task_id_value": "red_light_violation"},\n                    {"application_name": "Violence Detection", "task_id_value": "violence_detection"},\n                    {"application_name": "Loitering", "task_id_value": "dwell"},\n                    {"application_name": "Woman In Isolation", "task_id_value": "wii"},\n                    {"application_name": "Woman Hailing Help", "task_id_value": "whh"},\n                    {"application_name": "Queue Management", "task_id_value": "qm"},\n                    {"application_name": "Tailgating", "task_id_value": "tg"},\n                    {"application_name": "Lane violation", "task_id_value": "lane_violation"},\n                    {"application_name": "Seat belt", "task_id_value": "seatbelt"},\n                    {"application_name": "Parking violation", "task_id_value": "parking_violation"},\n                    {"application_name": "Person Attribute", "task_id_value": "pat"},\n                    {"application_name": "Vehicle Attribute", "task_id_value": "vat"},\n                    {"application_name": "Fire and Smoke Detection", "task_id_value": "fns"},\n                    {"application_name": "Parking violation", "task_id_value": "parking_violation"}\n                  ]\n              },\n              "camera_id": {\n                "bsonType": "string",\n                "description": "Individual camera identifier - use this field to filter events from specific cameras"\n              }\n            }\n          },\n          "response": {\n            "bsonType": "object",\n            "properties": {\n              "event": {\n                "bsonType": "object",\n                "properties": {\n                  "severity": {\n                    "bsonType": "string",\n                    "description": "Can be Low, Medium, Critical"\n                  },\n                  "blobs": {\n                    "bsonType": "array",\n                    "items": {\n                      "bsonType": "object",\n                      "properties": {\n                        "url": {\n                          "bsonType" ...

# %%
fdf= pd.read_csv("/Users/diwanshuyadav/Documents/Metafusion_NLP/sft_train_dataset.csv")

# %%
fdf["additional_info"]="na"
fdf['schema']=a

# %%
fdf.dropna(inplace=True)

# %%
fdf["schema"]=fdf["schema"].apply(lambda x: x.replace("\n", "").replace(" ", ""))

# %%
fdf.to_csv("sft_train_dataset_cs.csv")

# %%
df2['schema']=a

# %%
df2['schema']=df2["schema"].apply(lambda x: x.replace("\n", "").replace(" ", ""))

# %%
df2["schema"].iloc[0]
# Out:
# '{"collections":[{"name":"events","document":{"bsonType":"object","properties":{"identifier":{"bsonType":"object","properties":{"camgroup_id":{"bsonType":"string","description":"Usethistofiltereventsbygroup"},"task_id":{"bsonType":"string","description":"Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues","mappings":[{"application_name":"LicensePlateRecognition","task_id_value":"ANPR"},{"application_name":"CrowdEstimation","task_id_value":"CROWD_EST"},{"application_name":"CrowdCount","task_id_value":"CROWD_COUNT"},{"application_name":"FacialRecognition","task_id_value":"FR"},{"application_name":"AbandonedBagAlert","task_id_value":"ABANDONED_BAG"},{"application_name":"IntruderAlert","task_id_value":"INTRUDER_DETECT"},{"application_name":"CameraTampering","task_id_value":"CAM_TAMPERING"},{"application_name":"PersonSlipDetection","task_id_value":"SLIP_DETECT"},{"application_name":"PPEViolation","task_id_value":"PPE_VOILATION"},{"application_name":"WrongWay","task_id_value":"wrong_way"},{"application_name":"HelmetViolation","task_id_value":"helmet_violation"},{"application_name":"TripleRiding","task_id_value":"triple_riding"},{"application_name":"SpeedViolation","task_id_value":"speed_violation"},{"application_name":"RedLightViolation","task_id_value":"red_light_violation"},{"application_name":"ViolenceDetection","task_id_value":"violence_detection"},{"application_name":"Loitering","task_id_value":"dwell"},{"application_name":"WomanInIsolation","task_id_value":"wii"},{"application_name":"WomanHailingHelp","task_id_value":"whh"},{"application_name":"QueueManagement","task_id_value":"qm"},{"application_name":"Tailgating","task_id_value":"tg"},{"application_name":"Laneviolation","task_id_value":"lane_violation"},{"application_name":"Seatbelt","task_id_value":"seatbelt"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"},{"application_name":"PersonAttribute","task_id_value":"pat"},{"application_name":"VehicleAttribute","task_id_value":"vat"},{"application_name":"FireandSmokeDetection","task_id_value":"fns"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"}]},"camera_id":{"bsonType":"string","description":"Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras"}}},"response":{"bsonType":"object","properties":{"event":{"bsonType":"object","properties":{"severity":{"bsonType":"string","description":"CanbeLow,Medium,Critical"},"blobs":{"bsonType":"array","items":{"bsonType":"object","properties":{"url":{"bsonType":"string"},"attribs":{"bsonType":"object","description":"Attributesforpersonorvehicledetection","properties":{"footwear_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroffootwearforperson"},"carrying_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofitemsbeingcarried"},"lower_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroflowerbodyclothing"},"upper_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofupperbodyclothing"},"gender":{"bsonType":"string","enum":["female","male"],"description":"Genderoftheperson"},"age":{"bsonType":"string","enum":["child","adult","older_adult"],"description":"Agecategoryoftheperson"},"body_type":{"bsonType":"string","enum":["fat","normal","thin"],"description":"Bodytypeoftheperson"},"hair_type":{"bsonType":"string","enum":["bald_head","long_hair","short_hair"],"description":"Hairtypeoftheperson"},"hair_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Haircoloroftheperson"},"accessories":{"bsonType":"string","enum":["glasses","muffler","hat","nothing","he ...

# %%
mod_df = modify_dataframe_v3(df2)
# Out:
# 2025-06-22 22:40:07.145 | INFO     | shared.workspace.data_v3.data_utils.utils:modify_dataframe:128 - Modifying DataFrame...
# 2025-06-22 22:40:07.146 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:129 - input DataFrame length: 3660
# Modifying Queries: 100%|██████████| 3660/3660 [00:00<00:00, 25152.88it/s]
# 2025-06-22 22:40:09.138 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:135 - Modified queries length: 2122
# Testing Line-based Parsing: 100%|██████████| 2122/2122 [00:00<00:00, 502360.05it/s]
# 2025-06-22 22:40:09.143 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:137 - Line-based queries length: 2122
# Converting Schemas to Line-based Format: 100%|██████████| 2122/2122 [00:00<00:00, 81530.83it/s]
# 2025-06-22 22:40:09.170 | DEBUG    | shared.workspace.data_v3.data_utils.utils:modify_dataframe:139 - Modified schemas length: 2122

# %%
mod_df[4]
# Out:
# {'mongo_query': 'db.events.find({"response.event.blobs.attribs.footwear_color":"black"})',
#  'natural_language_query': 'Find events where a person is wearing black footwear.',
#  'additional_info': 'na',
#  'modified_query': {'footwear_color': 'black', '_original_numbers': {}},
#  'collection_name': 'events',
#  'in2out': {'camgroup_id': 'identifier.camgroup_id',
#   'task_id': 'identifier.task_id',
#   'camera_id': 'identifier.camera_id',
#   'severity': 'response.event.blobs.severity',
#   'url': 'response.event.blobs.url',
#   'footwear_color': 'response.event.blobs.attribs.footwear_color',
#   'carrying_color': 'response.event.blobs.attribs.carrying_color',
#   'lower_color': 'response.event.blobs.attribs.lower_color',
#   'upper_color': 'response.event.blobs.attribs.upper_color',
#   'gender': 'response.event.blobs.attribs.gender',
#   'age': 'response.event.blobs.attribs.age',
#   'body_type': 'response.event.blobs.attribs.body_type',
#   'hair_type': 'response.event.blobs.attribs.hair_type',
#   'hair_color': 'response.event.blobs.attribs.hair_color',
#   'accessories': 'response.event.blobs.attribs.accessories',
#   'sleeve_type': 'response.event.blobs.attribs.sleeve_type',
#   'orientation': 'response.event.blobs.attribs.orientation',
#   'actions': 'response.event.blobs.attribs.actions',
#   'upper_type': 'response.event.blobs.attribs.upper_type',
#   'footwear': 'response.event.blobs.attribs.footwear',
#   'carrying': 'response.event.blobs.attribs.carrying',
#   'lower_type': 'response.event.blobs.attribs.lower_type',
#   'brand_name': 'response.event.blobs.attribs.brand_name',
#   'vehicle_color': 'response.event.blobs.attribs.vehicle_color',
#   'vehicle_i_type': 'response.event.blobs.attribs.vehicle_i_type',
#   'vehicle_type': 'response.event.blobs.attribs.vehicle_type',
#   'special_type': 'response.event.blobs.attribs.special_type',
#   'label': 'response.event.blobs.label',
#   'score': 'response.event.blobs.score',
#   'match_id': 'response.event.blobs.match_id',
#   'subclass': 'response.event.blobs.subclass',
#   'c_timestamp': 'response.event.c_timestamp'},
#  'out2in': {'identifier.camgroup_id': 'camgroup_id',
#   'identifier.task_id': 'task_id',
#   'identifier.camera_id': 'camera_id',
#   'response.event.blobs.severity': 'severity',
#   'response.event.blobs.url': 'url',
#   'response.event.blobs.attribs.footwear_color': 'footwear_color',
#   'response.event.blobs.attribs.carrying_color': 'carrying_color',
#   'response.event.blobs.attribs.lower_color': 'lower_color',
#   'response.event.blobs.attribs.upper_color': 'upper_color',
#   'response.event.blobs.attribs.gender': 'gender',
#   'response.event.blobs.attribs.age': 'age',
#   'response.event.blobs.attribs.body_type': 'body_type',
#   'response.event.blobs.attribs.hair_type': 'hair_type',
#   'response.event.blobs.attribs.hair_color': 'hair_color',
#   'response.event.blobs.attribs.accessories': 'accessories',
#   'response.event.blobs.attribs.sleeve_type': 'sleeve_type',
#   'response.event.blobs.attribs.orientation': 'orientation',
#   'response.event.blobs.attribs.actions': 'actions',
#   'response.event.blobs.attribs.upper_type': 'upper_type',
#   'response.event.blobs.attribs.footwear': 'footwear',
#   'response.event.blobs.attribs.carrying': 'carrying',
#   'response.event.blobs.attribs.lower_type': 'lower_type',
#   'response.event.blobs.attribs.brand_name': 'brand_name',
#   'response.event.blobs.attribs.vehicle_color': 'vehicle_color',
#   'response.event.blobs.attribs.vehicle_i_type': 'vehicle_i_type',
#   'response.event.blobs.attribs.vehicle_type': 'vehicle_type',
#   'response.event.blobs.attribs.special_type': 'special_type',
#   'response.event.blobs.label': 'label',
#   'response.event.blobs.score': 'score',
#   'response.event.blobs.match_id': 'match_id',
#   'response.event.blobs.subclass': 'subclass',
#   'response.event.c_timestamp': 'c_timestamp'},
#  'schema': {'collections': [{'name': 'events',
#     'document': {'bsonType': 'object',
#      'properties': {'identifier': {'bsonType': 'object',
#        'properties': {'camgroup_id': {'bsonType': 'string',
#          'description': 'Usethistofiltereventsbygroup'},
#         'task_id': {'bsonType': 'string',
#          'description': 'Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues',
#          'mappings': [{'application_name': 'LicensePlateRecognition',
#            'task_id_value': 'ANPR'},
#           {'application_name': 'CrowdEstimation',
#            'task_id_value': 'CROWD_EST'},
#           {'application_name': 'CrowdCount', 'task_id_value': 'CROWD_COUNT'},
#           {'application_name': 'FacialRecognition', 'task_id_value': 'FR'},
#           {'application_name': 'AbandonedBagAlert',
#            'task_id_value': 'ABANDONED_BAG'},
#           {'application_name': 'IntruderAlert',
#            'task_id_value': 'INTRUDER_DETECT'},
#           {'application_name': 'CameraTampering',
#            'task_id_value': 'CAM_TAMPERING'},
#           {'application_name': 'PersonSlipDetection',
#            'task_id_value': 'SLIP_DETECT'},
#           {'application_name': 'PPEViolation',
#            'task_id_value': 'PPE_VOILATION'},
#           {'application_name': 'WrongWay', 'task_id_value': 'wrong_way'},
#           {'application_name': 'HelmetViolation',
#            'task_id_value': 'helmet_violation'},
#           {'application_name': 'TripleRiding',
#            'task_id_value': 'triple_riding'},
#           {'application_name': 'SpeedViolation',
#            'task_id_value': 'speed_violation'},
#           {'application_name': 'RedLightViolation',
#            'task_id_value': 'red_light_violation'},
#           {'application_name': 'ViolenceDetection',
#            'task_id_value': 'violence_detection'},
#           {'application_name': 'Loitering', 'task_id_value': 'dwell'},
#           {'application_name': 'WomanInIsolation', 'task_id_value': 'wii'},
#           {'application_name': 'WomanHailingHelp', 'task_id_value': 'whh'},
#           {'application_name': 'QueueManagement', 'task_id_value': 'qm'},
#           {'application_name': 'Tailgating', 'task_id_value': 'tg'},
#           {'application_name': 'Laneviolation',
#            'task_id_value': 'lane_violation'},
#           {'application_name': 'Seatbelt', 'task_id_value': 'seatbelt'},
#           {'application_name': 'Parkingviolation',
#            'task_id_value': 'parking_violation'},
#           {'application_name': 'PersonAttribute', 'task_id_value': 'pat'},
#           {'application_name': 'VehicleAttribute', 'task_id_value': 'vat'},
#           {'application_name': 'FireandSmokeDetection',
#            'task_id_value': 'fns'},
#           {'application_name': 'Parkingviolation',
#            'task_id_value': 'parking_violation'}]},
#         'camera_id': {'bsonType': 'string',
#          'description': 'Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras'}}},
#       'response': {'bsonType': 'object',
#        'properties': {'event': {'bsonType': 'object',
#          'properties': {'severity': {'bsonType': 'string',
#            'description': 'CanbeLow,Medium,Critical'},
#           'blobs': {'bsonType': 'array',
#            'items': {'bsonType': 'object',
#             'properties': {'url': {'bsonType': 'string'},
#              'attribs': {'bsonType': 'object',
#               'description': 'Attributesforpersonorvehicledetection',
#               'properties': {'footwear_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Coloroffootwearforperson'},
#                'carrying_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Colorofitemsbeingcarried'},
#                'lower_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Coloroflowerbodyclothing'},
#                'upper_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Colorofupperbodyclothing'},
#                'gender': {'bsonType': 'string',
#                 'enum': ['female', 'male'],
#                 'description': 'Genderoftheperson'},
#                'age': {'bsonType': 'string',
#                 'enum': ['child', 'adult', 'older_adult'],
#                 'description': 'Agecategoryoftheperson'},
#                'body_type': {'bsonType': 'string',
#                 'enum': ['fat', 'normal', 'thin'],
#                 'description': 'Bodytypeoftheperson'},
#                'hair_type': {'bsonType': 'string',
#                 'enum': ['bald_head', 'long_hair', 'short_hair'],
#                 'description': 'Hairtypeoftheperson'},
#                'hair_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Haircoloroftheperson'},
#                'accessories': {'bsonType': 'string',
#                 'enum': ['glasses',
#                  'muffler',
#                  'hat',
#                  'nothing',
#                  'headphone',
#                  'hair_band',
#                  'kerchief'],
#                 'description': 'Accessorieswornbytheperson'},
#                'sleeve_type': {'bsonType': 'string',
#                 'enum': ['short_sleeve', 'long_sleeve'],
#                 'description': 'Typeofsleevesonupperclothing'},
#                'orientation': {'bsonType': 'string',
#                 'enum': ['front', 'side', 'back'],
#                 'description': 'Orientationofpersonorvehicle'},
#                'actions': {'bsonType': 'string',
#                 'enum': ['calling',
#                  'talking',
#                  'gathering',
#                  'holding',
#                  'pushing',
#                  'pulling',
#                  'carry_arm',
#                  'carry_hand'],
#                 'description': 'Actionsbeingperformedbytheperson'},
#                'upper_type': {'bsonType': 'string',
#                 'enum': ['stride',
#                  'splice',
#                  'casual',
#                  'formal',
#                  'jacket',
#                  'logo',
#                  'plaid',
#                  'thin_stripes',
#                  'tshirt',
#                  'other',
#                  'v_neck',
#                  'suit',
#                  'thick_stripes',
#                  'shirt',
#                  'sweater',
#                  'vest',
#                  'cotton',
#                  'suit_up',
#                  'tight'],
#                 'description': 'Typeofupperbodyclothing'},
#                'footwear': {'bsonType': 'string',
#                 'enum': ['leather',
#                  'sport',
#                  'boots',
#                  'cloth',
#                  'casual',
#                  'sandals',
#                  'stocking',
#                  'leather_shoes',
#                  'shoes',
#                  'sneaker'],
#                 'description': 'Typeoffootwear'},
#                'carrying': {'bsonType': 'string',
#                 'enum': ['hand_bag',
#                  'shoulder_bag',
#                  'hold_objects_in_front',
#                  'backpack',
#                  'messenger_bag',
#                  'nothing',
#                  'plastic_bags',
#                  'baby_buggy',
#                  'shopping_trolley',
#                  'umbrella',
#                  'folder',
#                  'luggage_case',
#                  'suitcase',
#                  'box',
#                  'plastic_bag',
#                  'paper_bag',
#                  'hand_trunk',
#                  'other'],
#                 'description': 'Itemsbeingcarriedbytheperson'},
#                'lower_type': {'bsonType': 'string',
#                 'enum': ['stripe',
#                  'pattern',
#                  'long_coat',
#                  'trousers',
#                  'shorts',
#                  'skirt_and_dress',
#                  'boots',
#                  'long_trousers',
#                  'skirt',
#                  'short_skirt',
#                  'dress',
#                  'jeans',
#                  'tight_trousers',
#                  'capri',
#                  'hot_pants',
#                  'long_skirt',
#                  'plaid',
#                  'thin_stripes',
#                  'suits',
#                  'casual',
#                  'formal'],
#                 'description': 'Typeoflowerbodyclothing'},
#                'brand_name': {'bsonType': 'string',
#                 'enum': ['tvs',
#                  'maruti_suzuki',
#                  'eicher',
#                  'ashok_leyland',
#                  'mercedes_benz',
#                  'royal_enfield',
#                  'chevrolet',
#                  'fiat',
#                  'jaguar',
#                  'audi',
#                  'toyota',
#                  'sml',
#                  'bajaj',
#                  'jbm',
#                  'bharat_benz',
#                  'hero_motor',
#                  'volvo',
#                  'nissan',
#                  'renault',
#                  'volkswagen',
#                  'mazda',
#                  'hero_honda',
#                  'hyundai',
#                  'mg',
#                  'skoda',
#                  'land_rover',
#                  'yamaha',
#                  'kia',
#                  'mahindra',
#                  'mitsubishi',
#                  'ford',
#                  'jeep',
#                  'tata_motors',
#                  'honda',
#                  'bmw',
#                  'coupe',
#                  'force'],
#                 'description': 'Brandnameofthevehicle'},
#                'vehicle_color': {'bsonType': 'string',
#                 'enum': ['khakhi',
#                  'silver',
#                  'yellow',
#                  'pink',
#                  'purple',
#                  'green',
#                  'blue',
#                  'brown',
#                  'maroon',
#                  'red',
#                  'orange',
#                  'violet',
#                  'white',
#                  'black',
#                  'grey'],
#                 'description': 'Colorofthevehicle'},
#                'vehicle_i_type': {'bsonType': 'string',
#                 'enum': ['hmv',
#                  'lmv',
#                  'lgv',
#                  '3_axle',
#                  '5_axle',
#                  'mcwg',
#                  '6_axle',
#                  '2_axle',
#                  '4_axle',
#                  'heavy_vehicle'],
#                 'description': 'Vehicleclassificationtype'},
#                'vehicle_type': {'bsonType': 'string',
#                 'enum': ['sedan',
#                  'suv',
#                  'micro',
#                  'hatchback',
#                  'wagon',
#                  'pick_up',
#                  'convertible'],
#                 'description': 'Typeofvehicle'},
#                'special_type': {'bsonType': 'string',
#                 'enum': ['army_vehicle',
#                  'ambulance',
#                  'graminseva_4wheeler',
#                  'graminseva_3wheeler',
#                  'campervan'],
#                 'description': 'Specialvehicletype'}}},
#              'label': {'bsonType': 'string',
#               'enum': ['bus',
#                'car',
#                'truck',
#                'motorbike',
#                'bicycle',
#                'e_rikshaw',
#                'cycle_rikshaw',
#                'tractor',
#                'cement_mixer',
#                'mini_truck',
#                'mini_bus',
#                'mini_van',
#                'van'],
#               'description': 'Vehicletypewhattypeofvehicleisdetected'},
#              'score': {'bsonType': 'number',
#               'description': 'Confidencescoreforthedetection'},
#              'match_id': {'bsonType': 'string',
#               'description': 'MatchIDforpersonidentification'},
#              'severity': {'bsonType': 'string'},
#              'subclass': {'bsonType': 'string',
#               'description': 'Subclassforthedetectedobject'}}}},
#           'c_timestamp': {'bsonType': 'date',
#            'description': 'Timestampoftheevent'}}}}}}}}],
#   'version': 1},
#  'line_based_query': "footwear_color = 'black'",
#  'line_based_schema': 'identifier  // (object)\ncamgroup_id  // Usethistofiltereventsbygroup (string)\ntask_id  // Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues (string)\ncamera_id  // Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras (string)\nresponse  // (object)\nevent  // (object)\nseverity  // CanbeLow,Medium,Critical (string)\nblobs  // (array)\nurl  // (string)\nattribs  // Attributesforpersonorvehicledetection (object)\nfootwear_color  // Coloroffootwearforperson (string)\ncarrying_color  // Colorofitemsbeingcarried (string)\nlower_color  // Coloroflowerbodyclothing (string)\nupper_color  // Colorofupperbodyclothing (string)\ngender  // Genderoftheperson (string)\nage  // Agecategoryoftheperson (string)\nbody_type  // Bodytypeoftheperson (string)\nhair_type  // Hairtypeoftheperson (string)\nhair_color  // Haircoloroftheperson (string)\naccessories  // Accessorieswornbytheperson (string)\nsleeve_type  // Typeofsleevesonupperclothing (string)\norientation  // Orientationofpersonorvehicle (string)\nactions  // Actionsbeingperformedbytheperson (string)\nupper_type  // Typeofupperbodyclothing (string)\nfootwear  // Typeoffootwear (string)\ncarrying  // Itemsbeingcarriedbytheperson (string)\nlower_type  // Typeoflowerbodyclothing (string)\nbrand_name  // Brandnameofthevehicle (string)\nvehicle_color  // Colorofthevehicle (string)\nvehicle_i_type  // Vehicleclassificationtype (string)\nvehicle_type  // Typeofvehicle (string)\nspecial_type  // Specialvehicletype (string)\nlabel  // Vehicletypewhattypeofvehicleisdetected (string)\nscore  // Confidencescoreforthedetection (number)\nmatch_id  // MatchIDforpersonidentification (string)\nseverity  // (string)\nsubclass  // Subclassforthedetectedobject (string)\nc_timestamp  // Timestampoftheevent (date)'}

# %%
from shared.workspace.eval_v3.get_result import (
    reconstruct_original_query
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from shared.workspace.eval_v3.get_result import (
#       2     reconstruct_original_query
#       3 )
#
# File ~/Documents/Metafusion_NLP/shared/workspace/eval_v3/get_result.py:5
#       3 from typing import Dict, List, Any
#       4 from loguru import logger
# ----> 5 from data_v3.data_utils.utils import (
#       6     modify_dataframe as modify_dataframe_v3
#       7 )
#       8 from data_v3.data_utils.line_based_parsing import (
#       9     parse_line_based_query
#      10 )
#      11 from data_v3.data_utils.base_conversion_utils import (
#      12     build_schema_maps,
#      13     convert_modified_to_actual_code_string
#      14 )
#
# ModuleNotFoundError: No module named 'data_v3'

# %%
from shared.workspace.data_v3.data_utils.utils import (
    modify_dataframe as modify_dataframe_v3
)
from shared.workspace.data_v3.data_utils.line_based_parsing import (
    parse_line_based_query
)
from shared.workspace.data_v3.data_utils.base_conversion_utils import (
    build_schema_maps,
    convert_modified_to_actual_code_string
)

# %%
from typing import Dict, Any, List
from tqdm import tqdm
from loguru import logger

def convert_line_parsed_to_mongo(line_parsed: str, schema: Dict[str, Any]) -> str:
    try:
        print("0")
        modified_query = parse_line_based_query(line_parsed)
        print("1")
        collection_name = schema["collections"][0]["name"]
        in2out, _ = build_schema_maps(schema)
        print("2")
        reconstructed_query = convert_modified_to_actual_code_string(modified_query, in2out, collection_name)
        return reconstructed_query
    except Exception as e:
        logger.error(f"Error converting line parsed to MongoDB query: {e}")
        return ""

def reconstruct_original_query(data: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    for index, query_data in tqdm(enumerate(data), desc="Reconstructing Original Queries", total=len(data)):
        line_parsed = query_data["output"]
        schema = query_data["schema"]
        reconstructed_query = convert_line_parsed_to_mongo(line_parsed, schema)
        data[index]["reconstructed_query"] = reconstructed_query
    return data

# %%
for i in range(len(mod_df)):
    mod_df[i]["output"] = str(mod_df[i]["modified_query"])

# %%
type(mod_df[0]["output"])
# Out:
# str

# %%
re_df=reconstruct_original_query(mod_df[0:4])
# Out:
# Reconstructing Original Queries: 100%|██████████| 4/4 [00:00<00:00, 4819.65it/s]
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
re_df[2]
# Out:
# {'mongo_query': 'db.events.find({"response.event.severity":"medium"})',
#  'natural_language_query': 'List all alerts with severity medium.',
#  'additional_info': 'na',
#  'modified_query': {'response.event.severity': 'medium',
#   '_original_numbers': {}},
#  'collection_name': 'events',
#  'in2out': {'camgroup_id': 'identifier.camgroup_id',
#   'task_id': 'identifier.task_id',
#   'camera_id': 'identifier.camera_id',
#   'severity': 'response.event.blobs.severity',
#   'url': 'response.event.blobs.url',
#   'footwear_color': 'response.event.blobs.attribs.footwear_color',
#   'carrying_color': 'response.event.blobs.attribs.carrying_color',
#   'lower_color': 'response.event.blobs.attribs.lower_color',
#   'upper_color': 'response.event.blobs.attribs.upper_color',
#   'gender': 'response.event.blobs.attribs.gender',
#   'age': 'response.event.blobs.attribs.age',
#   'body_type': 'response.event.blobs.attribs.body_type',
#   'hair_type': 'response.event.blobs.attribs.hair_type',
#   'hair_color': 'response.event.blobs.attribs.hair_color',
#   'accessories': 'response.event.blobs.attribs.accessories',
#   'sleeve_type': 'response.event.blobs.attribs.sleeve_type',
#   'orientation': 'response.event.blobs.attribs.orientation',
#   'actions': 'response.event.blobs.attribs.actions',
#   'upper_type': 'response.event.blobs.attribs.upper_type',
#   'footwear': 'response.event.blobs.attribs.footwear',
#   'carrying': 'response.event.blobs.attribs.carrying',
#   'lower_type': 'response.event.blobs.attribs.lower_type',
#   'brand_name': 'response.event.blobs.attribs.brand_name',
#   'vehicle_color': 'response.event.blobs.attribs.vehicle_color',
#   'vehicle_i_type': 'response.event.blobs.attribs.vehicle_i_type',
#   'vehicle_type': 'response.event.blobs.attribs.vehicle_type',
#   'special_type': 'response.event.blobs.attribs.special_type',
#   'label': 'response.event.blobs.label',
#   'score': 'response.event.blobs.score',
#   'match_id': 'response.event.blobs.match_id',
#   'subclass': 'response.event.blobs.subclass',
#   'c_timestamp': 'response.event.c_timestamp'},
#  'out2in': {'identifier.camgroup_id': 'camgroup_id',
#   'identifier.task_id': 'task_id',
#   'identifier.camera_id': 'camera_id',
#   'response.event.blobs.severity': 'severity',
#   'response.event.blobs.url': 'url',
#   'response.event.blobs.attribs.footwear_color': 'footwear_color',
#   'response.event.blobs.attribs.carrying_color': 'carrying_color',
#   'response.event.blobs.attribs.lower_color': 'lower_color',
#   'response.event.blobs.attribs.upper_color': 'upper_color',
#   'response.event.blobs.attribs.gender': 'gender',
#   'response.event.blobs.attribs.age': 'age',
#   'response.event.blobs.attribs.body_type': 'body_type',
#   'response.event.blobs.attribs.hair_type': 'hair_type',
#   'response.event.blobs.attribs.hair_color': 'hair_color',
#   'response.event.blobs.attribs.accessories': 'accessories',
#   'response.event.blobs.attribs.sleeve_type': 'sleeve_type',
#   'response.event.blobs.attribs.orientation': 'orientation',
#   'response.event.blobs.attribs.actions': 'actions',
#   'response.event.blobs.attribs.upper_type': 'upper_type',
#   'response.event.blobs.attribs.footwear': 'footwear',
#   'response.event.blobs.attribs.carrying': 'carrying',
#   'response.event.blobs.attribs.lower_type': 'lower_type',
#   'response.event.blobs.attribs.brand_name': 'brand_name',
#   'response.event.blobs.attribs.vehicle_color': 'vehicle_color',
#   'response.event.blobs.attribs.vehicle_i_type': 'vehicle_i_type',
#   'response.event.blobs.attribs.vehicle_type': 'vehicle_type',
#   'response.event.blobs.attribs.special_type': 'special_type',
#   'response.event.blobs.label': 'label',
#   'response.event.blobs.score': 'score',
#   'response.event.blobs.match_id': 'match_id',
#   'response.event.blobs.subclass': 'subclass',
#   'response.event.c_timestamp': 'c_timestamp'},
#  'schema': {'collections': [{'name': 'events',
#     'document': {'bsonType': 'object',
#      'properties': {'identifier': {'bsonType': 'object',
#        'properties': {'camgroup_id': {'bsonType': 'string',
#          'description': 'Usethistofiltereventsbygroup'},
#         'task_id': {'bsonType': 'string',
#          'description': 'Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues',
#          'mappings': [{'application_name': 'LicensePlateRecognition',
#            'task_id_value': 'ANPR'},
#           {'application_name': 'CrowdEstimation',
#            'task_id_value': 'CROWD_EST'},
#           {'application_name': 'CrowdCount', 'task_id_value': 'CROWD_COUNT'},
#           {'application_name': 'FacialRecognition', 'task_id_value': 'FR'},
#           {'application_name': 'AbandonedBagAlert',
#            'task_id_value': 'ABANDONED_BAG'},
#           {'application_name': 'IntruderAlert',
#            'task_id_value': 'INTRUDER_DETECT'},
#           {'application_name': 'CameraTampering',
#            'task_id_value': 'CAM_TAMPERING'},
#           {'application_name': 'PersonSlipDetection',
#            'task_id_value': 'SLIP_DETECT'},
#           {'application_name': 'PPEViolation',
#            'task_id_value': 'PPE_VOILATION'},
#           {'application_name': 'WrongWay', 'task_id_value': 'wrong_way'},
#           {'application_name': 'HelmetViolation',
#            'task_id_value': 'helmet_violation'},
#           {'application_name': 'TripleRiding',
#            'task_id_value': 'triple_riding'},
#           {'application_name': 'SpeedViolation',
#            'task_id_value': 'speed_violation'},
#           {'application_name': 'RedLightViolation',
#            'task_id_value': 'red_light_violation'},
#           {'application_name': 'ViolenceDetection',
#            'task_id_value': 'violence_detection'},
#           {'application_name': 'Loitering', 'task_id_value': 'dwell'},
#           {'application_name': 'WomanInIsolation', 'task_id_value': 'wii'},
#           {'application_name': 'WomanHailingHelp', 'task_id_value': 'whh'},
#           {'application_name': 'QueueManagement', 'task_id_value': 'qm'},
#           {'application_name': 'Tailgating', 'task_id_value': 'tg'},
#           {'application_name': 'Laneviolation',
#            'task_id_value': 'lane_violation'},
#           {'application_name': 'Seatbelt', 'task_id_value': 'seatbelt'},
#           {'application_name': 'Parkingviolation',
#            'task_id_value': 'parking_violation'},
#           {'application_name': 'PersonAttribute', 'task_id_value': 'pat'},
#           {'application_name': 'VehicleAttribute', 'task_id_value': 'vat'},
#           {'application_name': 'FireandSmokeDetection',
#            'task_id_value': 'fns'},
#           {'application_name': 'Parkingviolation',
#            'task_id_value': 'parking_violation'}]},
#         'camera_id': {'bsonType': 'string',
#          'description': 'Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras'}}},
#       'response': {'bsonType': 'object',
#        'properties': {'event': {'bsonType': 'object',
#          'properties': {'severity': {'bsonType': 'string',
#            'description': 'CanbeLow,Medium,Critical'},
#           'blobs': {'bsonType': 'array',
#            'items': {'bsonType': 'object',
#             'properties': {'url': {'bsonType': 'string'},
#              'attribs': {'bsonType': 'object',
#               'description': 'Attributesforpersonorvehicledetection',
#               'properties': {'footwear_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Coloroffootwearforperson'},
#                'carrying_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Colorofitemsbeingcarried'},
#                'lower_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Coloroflowerbodyclothing'},
#                'upper_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Colorofupperbodyclothing'},
#                'gender': {'bsonType': 'string',
#                 'enum': ['female', 'male'],
#                 'description': 'Genderoftheperson'},
#                'age': {'bsonType': 'string',
#                 'enum': ['child', 'adult', 'older_adult'],
#                 'description': 'Agecategoryoftheperson'},
#                'body_type': {'bsonType': 'string',
#                 'enum': ['fat', 'normal', 'thin'],
#                 'description': 'Bodytypeoftheperson'},
#                'hair_type': {'bsonType': 'string',
#                 'enum': ['bald_head', 'long_hair', 'short_hair'],
#                 'description': 'Hairtypeoftheperson'},
#                'hair_color': {'bsonType': 'string',
#                 'enum': ['black',
#                  'blue',
#                  'brown',
#                  'green',
#                  'grey',
#                  'orange',
#                  'pink',
#                  'purple',
#                  'red',
#                  'white',
#                  'yellow'],
#                 'description': 'Haircoloroftheperson'},
#                'accessories': {'bsonType': 'string',
#                 'enum': ['glasses',
#                  'muffler',
#                  'hat',
#                  'nothing',
#                  'headphone',
#                  'hair_band',
#                  'kerchief'],
#                 'description': 'Accessorieswornbytheperson'},
#                'sleeve_type': {'bsonType': 'string',
#                 'enum': ['short_sleeve', 'long_sleeve'],
#                 'description': 'Typeofsleevesonupperclothing'},
#                'orientation': {'bsonType': 'string',
#                 'enum': ['front', 'side', 'back'],
#                 'description': 'Orientationofpersonorvehicle'},
#                'actions': {'bsonType': 'string',
#                 'enum': ['calling',
#                  'talking',
#                  'gathering',
#                  'holding',
#                  'pushing',
#                  'pulling',
#                  'carry_arm',
#                  'carry_hand'],
#                 'description': 'Actionsbeingperformedbytheperson'},
#                'upper_type': {'bsonType': 'string',
#                 'enum': ['stride',
#                  'splice',
#                  'casual',
#                  'formal',
#                  'jacket',
#                  'logo',
#                  'plaid',
#                  'thin_stripes',
#                  'tshirt',
#                  'other',
#                  'v_neck',
#                  'suit',
#                  'thick_stripes',
#                  'shirt',
#                  'sweater',
#                  'vest',
#                  'cotton',
#                  'suit_up',
#                  'tight'],
#                 'description': 'Typeofupperbodyclothing'},
#                'footwear': {'bsonType': 'string',
#                 'enum': ['leather',
#                  'sport',
#                  'boots',
#                  'cloth',
#                  'casual',
#                  'sandals',
#                  'stocking',
#                  'leather_shoes',
#                  'shoes',
#                  'sneaker'],
#                 'description': 'Typeoffootwear'},
#                'carrying': {'bsonType': 'string',
#                 'enum': ['hand_bag',
#                  'shoulder_bag',
#                  'hold_objects_in_front',
#                  'backpack',
#                  'messenger_bag',
#                  'nothing',
#                  'plastic_bags',
#                  'baby_buggy',
#                  'shopping_trolley',
#                  'umbrella',
#                  'folder',
#                  'luggage_case',
#                  'suitcase',
#                  'box',
#                  'plastic_bag',
#                  'paper_bag',
#                  'hand_trunk',
#                  'other'],
#                 'description': 'Itemsbeingcarriedbytheperson'},
#                'lower_type': {'bsonType': 'string',
#                 'enum': ['stripe',
#                  'pattern',
#                  'long_coat',
#                  'trousers',
#                  'shorts',
#                  'skirt_and_dress',
#                  'boots',
#                  'long_trousers',
#                  'skirt',
#                  'short_skirt',
#                  'dress',
#                  'jeans',
#                  'tight_trousers',
#                  'capri',
#                  'hot_pants',
#                  'long_skirt',
#                  'plaid',
#                  'thin_stripes',
#                  'suits',
#                  'casual',
#                  'formal'],
#                 'description': 'Typeoflowerbodyclothing'},
#                'brand_name': {'bsonType': 'string',
#                 'enum': ['tvs',
#                  'maruti_suzuki',
#                  'eicher',
#                  'ashok_leyland',
#                  'mercedes_benz',
#                  'royal_enfield',
#                  'chevrolet',
#                  'fiat',
#                  'jaguar',
#                  'audi',
#                  'toyota',
#                  'sml',
#                  'bajaj',
#                  'jbm',
#                  'bharat_benz',
#                  'hero_motor',
#                  'volvo',
#                  'nissan',
#                  'renault',
#                  'volkswagen',
#                  'mazda',
#                  'hero_honda',
#                  'hyundai',
#                  'mg',
#                  'skoda',
#                  'land_rover',
#                  'yamaha',
#                  'kia',
#                  'mahindra',
#                  'mitsubishi',
#                  'ford',
#                  'jeep',
#                  'tata_motors',
#                  'honda',
#                  'bmw',
#                  'coupe',
#                  'force'],
#                 'description': 'Brandnameofthevehicle'},
#                'vehicle_color': {'bsonType': 'string',
#                 'enum': ['khakhi',
#                  'silver',
#                  'yellow',
#                  'pink',
#                  'purple',
#                  'green',
#                  'blue',
#                  'brown',
#                  'maroon',
#                  'red',
#                  'orange',
#                  'violet',
#                  'white',
#                  'black',
#                  'grey'],
#                 'description': 'Colorofthevehicle'},
#                'vehicle_i_type': {'bsonType': 'string',
#                 'enum': ['hmv',
#                  'lmv',
#                  'lgv',
#                  '3_axle',
#                  '5_axle',
#                  'mcwg',
#                  '6_axle',
#                  '2_axle',
#                  '4_axle',
#                  'heavy_vehicle'],
#                 'description': 'Vehicleclassificationtype'},
#                'vehicle_type': {'bsonType': 'string',
#                 'enum': ['sedan',
#                  'suv',
#                  'micro',
#                  'hatchback',
#                  'wagon',
#                  'pick_up',
#                  'convertible'],
#                 'description': 'Typeofvehicle'},
#                'special_type': {'bsonType': 'string',
#                 'enum': ['army_vehicle',
#                  'ambulance',
#                  'graminseva_4wheeler',
#                  'graminseva_3wheeler',
#                  'campervan'],
#                 'description': 'Specialvehicletype'}}},
#              'label': {'bsonType': 'string',
#               'enum': ['bus',
#                'car',
#                'truck',
#                'motorbike',
#                'bicycle',
#                'e_rikshaw',
#                'cycle_rikshaw',
#                'tractor',
#                'cement_mixer',
#                'mini_truck',
#                'mini_bus',
#                'mini_van',
#                'van'],
#               'description': 'Vehicletypewhattypeofvehicleisdetected'},
#              'score': {'bsonType': 'number',
#               'description': 'Confidencescoreforthedetection'},
#              'match_id': {'bsonType': 'string',
#               'description': 'MatchIDforpersonidentification'},
#              'severity': {'bsonType': 'string'},
#              'subclass': {'bsonType': 'string',
#               'description': 'Subclassforthedetectedobject'}}}},
#           'c_timestamp': {'bsonType': 'date',
#            'description': 'Timestampoftheevent'}}}}}}}}],
#   'version': 1},
#  'line_based_query': "response.event.severity = 'medium'",
#  'line_based_schema': 'identifier  // (object)\ncamgroup_id  // Usethistofiltereventsbygroup (string)\ntask_id  // Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues (string)\ncamera_id  // Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras (string)\nresponse  // (object)\nevent  // (object)\nseverity  // CanbeLow,Medium,Critical (string)\nblobs  // (array)\nurl  // (string)\nattribs  // Attributesforpersonorvehicledetection (object)\nfootwear_color  // Coloroffootwearforperson (string)\ncarrying_color  // Colorofitemsbeingcarried (string)\nlower_color  // Coloroflowerbodyclothing (string)\nupper_color  // Colorofupperbodyclothing (string)\ngender  // Genderoftheperson (string)\nage  // Agecategoryoftheperson (string)\nbody_type  // Bodytypeoftheperson (string)\nhair_type  // Hairtypeoftheperson (string)\nhair_color  // Haircoloroftheperson (string)\naccessories  // Accessorieswornbytheperson (string)\nsleeve_type  // Typeofsleevesonupperclothing (string)\norientation  // Orientationofpersonorvehicle (string)\nactions  // Actionsbeingperformedbytheperson (string)\nupper_type  // Typeofupperbodyclothing (string)\nfootwear  // Typeoffootwear (string)\ncarrying  // Itemsbeingcarriedbytheperson (string)\nlower_type  // Typeoflowerbodyclothing (string)\nbrand_name  // Brandnameofthevehicle (string)\nvehicle_color  // Colorofthevehicle (string)\nvehicle_i_type  // Vehicleclassificationtype (string)\nvehicle_type  // Typeofvehicle (string)\nspecial_type  // Specialvehicletype (string)\nlabel  // Vehicletypewhattypeofvehicleisdetected (string)\nscore  // Confidencescoreforthedetection (number)\nmatch_id  // MatchIDforpersonidentification (string)\nseverity  // (string)\nsubclass  // Subclassforthedetectedobject (string)\nc_timestamp  // Timestampoftheevent (date)',
#  'output': "{'response.event.severity': 'medium', '_original_numbers': {}}",
#  'reconstructed_query': 'db.events.find({"{\'response.event.severity\':":{"$\'medium\',":"\'_original_numbers\': {}}"}})'}

# %%
schema ="""'{"collections":[{"name":"events","document":{"bsonType":"object","properties":{"identifier":{"bsonType":"object","properties":{"camgroup_id":{"bsonType":"string","description":"Usethistofiltereventsbygroup"},"task_id":{"bsonType":"string","description":"Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues","mappings":[{"application_name":"LicensePlateRecognition","task_id_value":"ANPR"},{"application_name":"CrowdEstimation","task_id_value":"CROWD_EST"},{"application_name":"CrowdCount","task_id_value":"CROWD_COUNT"},{"application_name":"FacialRecognition","task_id_value":"FR"},{"application_name":"AbandonedBagAlert","task_id_value":"ABANDONED_BAG"},{"application_name":"IntruderAlert","task_id_value":"INTRUDER_DETECT"},{"application_name":"CameraTampering","task_id_value":"CAM_TAMPERING"},{"application_name":"PersonSlipDetection","task_id_value":"SLIP_DETECT"},{"application_name":"PPEViolation","task_id_value":"PPE_VOILATION"},{"application_name":"WrongWay","task_id_value":"wrong_way"},{"application_name":"HelmetViolation","task_id_value":"helmet_violation"},{"application_name":"TripleRiding","task_id_value":"triple_riding"},{"application_name":"SpeedViolation","task_id_value":"speed_violation"},{"application_name":"RedLightViolation","task_id_value":"red_light_violation"},{"application_name":"ViolenceDetection","task_id_value":"violence_detection"},{"application_name":"Loitering","task_id_value":"dwell"},{"application_name":"WomanInIsolation","task_id_value":"wii"},{"application_name":"WomanHailingHelp","task_id_value":"whh"},{"application_name":"QueueManagement","task_id_value":"qm"},{"application_name":"Tailgating","task_id_value":"tg"},{"application_name":"Laneviolation","task_id_value":"lane_violation"},{"application_name":"Seatbelt","task_id_value":"seatbelt"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"},{"application_name":"PersonAttribute","task_id_value":"pat"},{"application_name":"VehicleAttribute","task_id_value":"vat"},{"application_name":"FireandSmokeDetection","task_id_value":"fns"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"}]},"camera_id":{"bsonType":"string","description":"Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras"}}},"response":{"bsonType":"object","properties":{"event":{"bsonType":"object","properties":{"severity":{"bsonType":"string","description":"CanbeLow,Medium,Critical"},"blobs":{"bsonType":"array","items":{"bsonType":"object","properties":{"url":{"bsonType":"string"},"attribs":{"bsonType":"object","description":"Attributesforpersonorvehicledetection","properties":{"footwear_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroffootwearforperson"},"carrying_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofitemsbeingcarried"},"lower_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroflowerbodyclothing"},"upper_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofupperbodyclothing"},"gender":{"bsonType":"string","enum":["female","male"],"description":"Genderoftheperson"},"age":{"bsonType":"string","enum":["child","adult","older_adult"],"description":"Agecategoryoftheperson"},"body_type":{"bsonType":"string","enum":["fat","normal","thin"],"description":"Bodytypeoftheperson"},"hair_type":{"bsonType":"string","enum":["bald_head","long_hair","short_hair"],"description":"Hairtypeoftheperson"},"hair_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Haircoloroftheperson"},"accessories":{"bsonType":"string","enum":["glasses","muffler","hat","nothing","headphone","hair_band","kerchief"],"description":"Accessorieswornbytheperson"},"sleeve_type":{"bsonType":"string","enum":["short_sleeve","long_sleeve"],"description":"Typeofsleevesonupperclothing"},"orientation":{"bsonType":"string","enum":["front","side","back"],"description":"Orientationofpersonorvehicle"},"actions":{"bsonType":"string","enum":["calling","talking","gathering","holding","pushing","pulling","carry_arm","carry_hand"],"description":"Actionsbeingperformedbytheperson"},"upper_type":{"bsonType":"string","enum":["stride","splice","casual","formal","jacket","logo","plaid","thin_stripes","tshirt","other","v_neck","suit","thick_stripes","shirt","sweater","vest","cotton","suit_up","tight"],"description":"Typeofupperbodyclothing"},"footwear":{"bsonType":"string","enum":["leather","sport","boots","cloth","casual","sandals","stocking","leather_shoes","shoes","sneaker"],"description":"Typeoffootwear"},"carrying":{"bsonType":"string","enum":["hand_bag","shoulder_bag","hold_objects_in_front","backpack","messenger_bag","nothing","plastic_bags","baby_buggy","shopping_trolley","umbrella","folder","luggage_case","suitcase","box","plastic_bag","paper_bag","hand_trunk","other"],"description":"Itemsbeingcarriedbytheperson"},"lower_type":{"bsonType":"string","enum":["stripe","pattern","long_coat","trousers","shorts","skirt_and_dress","boots","long_trousers","skirt","short_skirt","dress","jeans","tight_trousers","capri","hot_pants","long_skirt","plaid","thin_stripes","suits","casual","formal"],"description":"Typeoflowerbodyclothing"},"brand_name":{"bsonType":"string","enum":["tvs","maruti_suzuki","eicher","ashok_leyland","mercedes_benz","royal_enfield","chevrolet","fiat","jaguar","audi","toyota","sml","bajaj","jbm","bharat_benz","hero_motor","volvo","nissan","renault","volkswagen","mazda","hero_honda","hyundai","mg","skoda","land_rover","yamaha","kia","mahindra","mitsubishi","ford","jeep","tata_motors","honda","bmw","coupe","force"],"description":"Brandnameofthevehicle"},"vehicle_color":{"bsonType":"string","enum":["khakhi","silver","yellow","pink","purple","green","blue","brown","maroon","red","orange","violet","white","black","grey"],"description":"Colorofthevehicle"},"vehicle_i_type":{"bsonType":"string","enum":["hmv","lmv","lgv","3_axle","5_axle","mcwg","6_axle","2_axle","4_axle","heavy_vehicle"],"description":"Vehicleclassificationtype"},"vehicle_type":{"bsonType":"string","enum":["sedan","suv","micro","hatchback","wagon","pick_up","convertible"],"description":"Typeofvehicle"},"special_type":{"bsonType":"string","enum":["army_vehicle","ambulance","graminseva_4wheeler","graminseva_3wheeler","campervan"],"description":"Specialvehicletype"}}},"label":{"bsonType":"string","enum":["bus","car","truck","motorbike","bicycle","e_rikshaw","cycle_rikshaw","tractor","cement_mixer","mini_truck","mini_bus","mini_van","van"],"description":"Vehicletypewhattypeofvehicleisdetected"},"score":{"bsonType":"number","description":"Confidencescoreforthedetection"},"match_id":{"bsonType":"string","description":"MatchIDforpersonidentification"},"severity":{"bsonType":"string"},"subclass":{"bsonType":"string","description":"Subclassforthedetectedobject"}}}},"c_timestamp":{"bsonType":"date","description":"Timestampoftheevent"}}}}}}}}],"version":1}'"""

# %%
schema
# Out:
# '\'{"collections":[{"name":"events","document":{"bsonType":"object","properties":{"identifier":{"bsonType":"object","properties":{"camgroup_id":{"bsonType":"string","description":"Usethistofiltereventsbygroup"},"task_id":{"bsonType":"string","description":"Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues","mappings":[{"application_name":"LicensePlateRecognition","task_id_value":"ANPR"},{"application_name":"CrowdEstimation","task_id_value":"CROWD_EST"},{"application_name":"CrowdCount","task_id_value":"CROWD_COUNT"},{"application_name":"FacialRecognition","task_id_value":"FR"},{"application_name":"AbandonedBagAlert","task_id_value":"ABANDONED_BAG"},{"application_name":"IntruderAlert","task_id_value":"INTRUDER_DETECT"},{"application_name":"CameraTampering","task_id_value":"CAM_TAMPERING"},{"application_name":"PersonSlipDetection","task_id_value":"SLIP_DETECT"},{"application_name":"PPEViolation","task_id_value":"PPE_VOILATION"},{"application_name":"WrongWay","task_id_value":"wrong_way"},{"application_name":"HelmetViolation","task_id_value":"helmet_violation"},{"application_name":"TripleRiding","task_id_value":"triple_riding"},{"application_name":"SpeedViolation","task_id_value":"speed_violation"},{"application_name":"RedLightViolation","task_id_value":"red_light_violation"},{"application_name":"ViolenceDetection","task_id_value":"violence_detection"},{"application_name":"Loitering","task_id_value":"dwell"},{"application_name":"WomanInIsolation","task_id_value":"wii"},{"application_name":"WomanHailingHelp","task_id_value":"whh"},{"application_name":"QueueManagement","task_id_value":"qm"},{"application_name":"Tailgating","task_id_value":"tg"},{"application_name":"Laneviolation","task_id_value":"lane_violation"},{"application_name":"Seatbelt","task_id_value":"seatbelt"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"},{"application_name":"PersonAttribute","task_id_value":"pat"},{"application_name":"VehicleAttribute","task_id_value":"vat"},{"application_name":"FireandSmokeDetection","task_id_value":"fns"},{"application_name":"Parkingviolation","task_id_value":"parking_violation"}]},"camera_id":{"bsonType":"string","description":"Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras"}}},"response":{"bsonType":"object","properties":{"event":{"bsonType":"object","properties":{"severity":{"bsonType":"string","description":"CanbeLow,Medium,Critical"},"blobs":{"bsonType":"array","items":{"bsonType":"object","properties":{"url":{"bsonType":"string"},"attribs":{"bsonType":"object","description":"Attributesforpersonorvehicledetection","properties":{"footwear_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroffootwearforperson"},"carrying_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofitemsbeingcarried"},"lower_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Coloroflowerbodyclothing"},"upper_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Colorofupperbodyclothing"},"gender":{"bsonType":"string","enum":["female","male"],"description":"Genderoftheperson"},"age":{"bsonType":"string","enum":["child","adult","older_adult"],"description":"Agecategoryoftheperson"},"body_type":{"bsonType":"string","enum":["fat","normal","thin"],"description":"Bodytypeoftheperson"},"hair_type":{"bsonType":"string","enum":["bald_head","long_hair","short_hair"],"description":"Hairtypeoftheperson"},"hair_color":{"bsonType":"string","enum":["black","blue","brown","green","grey","orange","pink","purple","red","white","yellow"],"description":"Haircoloroftheperson"},"accessories":{"bsonType":"string","enum":["glasses","muffler","hat","nothing"," ...

# %%
import json

# %%
json.loads(schema.strip("'"))
# Out:
# {'collections': [{'name': 'events',
#    'document': {'bsonType': 'object',
#     'properties': {'identifier': {'bsonType': 'object',
#       'properties': {'camgroup_id': {'bsonType': 'string',
#         'description': 'Usethistofiltereventsbygroup'},
#        'task_id': {'bsonType': 'string',
#         'description': 'Mapnaturallanguageapplicationnamestotheircorrespondingshort_namevalues',
#         'mappings': [{'application_name': 'LicensePlateRecognition',
#           'task_id_value': 'ANPR'},
#          {'application_name': 'CrowdEstimation', 'task_id_value': 'CROWD_EST'},
#          {'application_name': 'CrowdCount', 'task_id_value': 'CROWD_COUNT'},
#          {'application_name': 'FacialRecognition', 'task_id_value': 'FR'},
#          {'application_name': 'AbandonedBagAlert',
#           'task_id_value': 'ABANDONED_BAG'},
#          {'application_name': 'IntruderAlert',
#           'task_id_value': 'INTRUDER_DETECT'},
#          {'application_name': 'CameraTampering',
#           'task_id_value': 'CAM_TAMPERING'},
#          {'application_name': 'PersonSlipDetection',
#           'task_id_value': 'SLIP_DETECT'},
#          {'application_name': 'PPEViolation',
#           'task_id_value': 'PPE_VOILATION'},
#          {'application_name': 'WrongWay', 'task_id_value': 'wrong_way'},
#          {'application_name': 'HelmetViolation',
#           'task_id_value': 'helmet_violation'},
#          {'application_name': 'TripleRiding',
#           'task_id_value': 'triple_riding'},
#          {'application_name': 'SpeedViolation',
#           'task_id_value': 'speed_violation'},
#          {'application_name': 'RedLightViolation',
#           'task_id_value': 'red_light_violation'},
#          {'application_name': 'ViolenceDetection',
#           'task_id_value': 'violence_detection'},
#          {'application_name': 'Loitering', 'task_id_value': 'dwell'},
#          {'application_name': 'WomanInIsolation', 'task_id_value': 'wii'},
#          {'application_name': 'WomanHailingHelp', 'task_id_value': 'whh'},
#          {'application_name': 'QueueManagement', 'task_id_value': 'qm'},
#          {'application_name': 'Tailgating', 'task_id_value': 'tg'},
#          {'application_name': 'Laneviolation',
#           'task_id_value': 'lane_violation'},
#          {'application_name': 'Seatbelt', 'task_id_value': 'seatbelt'},
#          {'application_name': 'Parkingviolation',
#           'task_id_value': 'parking_violation'},
#          {'application_name': 'PersonAttribute', 'task_id_value': 'pat'},
#          {'application_name': 'VehicleAttribute', 'task_id_value': 'vat'},
#          {'application_name': 'FireandSmokeDetection', 'task_id_value': 'fns'},
#          {'application_name': 'Parkingviolation',
#           'task_id_value': 'parking_violation'}]},
#        'camera_id': {'bsonType': 'string',
#         'description': 'Individualcameraidentifier-usethisfieldtofiltereventsfromspecificcameras'}}},
#      'response': {'bsonType': 'object',
#       'properties': {'event': {'bsonType': 'object',
#         'properties': {'severity': {'bsonType': 'string',
#           'description': 'CanbeLow,Medium,Critical'},
#          'blobs': {'bsonType': 'array',
#           'items': {'bsonType': 'object',
#            'properties': {'url': {'bsonType': 'string'},
#             'attribs': {'bsonType': 'object',
#              'description': 'Attributesforpersonorvehicledetection',
#              'properties': {'footwear_color': {'bsonType': 'string',
#                'enum': ['black',
#                 'blue',
#                 'brown',
#                 'green',
#                 'grey',
#                 'orange',
#                 'pink',
#                 'purple',
#                 'red',
#                 'white',
#                 'yellow'],
#                'description': 'Coloroffootwearforperson'},
#               'carrying_color': {'bsonType': 'string',
#                'enum': ['black',
#                 'blue',
#                 'brown',
#                 'green',
#                 'grey',
#                 'orange',
#                 'pink',
#                 'purple',
#                 'red',
#                 'white',
#                 'yellow'],
#                'description': 'Colorofitemsbeingcarried'},
#               'lower_color': {'bsonType': 'string',
#                'enum': ['black',
#                 'blue',
#                 'brown',
#                 'green',
#                 'grey',
#                 'orange',
#                 'pink',
#                 'purple',
#                 'red',
#                 'white',
#                 'yellow'],
#                'description': 'Coloroflowerbodyclothing'},
#               'upper_color': {'bsonType': 'string',
#                'enum': ['black',
#                 'blue',
#                 'brown',
#                 'green',
#                 'grey',
#                 'orange',
#                 'pink',
#                 'purple',
#                 'red',
#                 'white',
#                 'yellow'],
#                'description': 'Colorofupperbodyclothing'},
#               'gender': {'bsonType': 'string',
#                'enum': ['female', 'male'],
#                'description': 'Genderoftheperson'},
#               'age': {'bsonType': 'string',
#                'enum': ['child', 'adult', 'older_adult'],
#                'description': 'Agecategoryoftheperson'},
#               'body_type': {'bsonType': 'string',
#                'enum': ['fat', 'normal', 'thin'],
#                'description': 'Bodytypeoftheperson'},
#               'hair_type': {'bsonType': 'string',
#                'enum': ['bald_head', 'long_hair', 'short_hair'],
#                'description': 'Hairtypeoftheperson'},
#               'hair_color': {'bsonType': 'string',
#                'enum': ['black',
#                 'blue',
#                 'brown',
#                 'green',
#                 'grey',
#                 'orange',
#                 'pink',
#                 'purple',
#                 'red',
#                 'white',
#                 'yellow'],
#                'description': 'Haircoloroftheperson'},
#               'accessories': {'bsonType': 'string',
#                'enum': ['glasses',
#                 'muffler',
#                 'hat',
#                 'nothing',
#                 'headphone',
#                 'hair_band',
#                 'kerchief'],
#                'description': 'Accessorieswornbytheperson'},
#               'sleeve_type': {'bsonType': 'string',
#                'enum': ['short_sleeve', 'long_sleeve'],
#                'description': 'Typeofsleevesonupperclothing'},
#               'orientation': {'bsonType': 'string',
#                'enum': ['front', 'side', 'back'],
#                'description': 'Orientationofpersonorvehicle'},
#               'actions': {'bsonType': 'string',
#                'enum': ['calling',
#                 'talking',
#                 'gathering',
#                 'holding',
#                 'pushing',
#                 'pulling',
#                 'carry_arm',
#                 'carry_hand'],
#                'description': 'Actionsbeingperformedbytheperson'},
#               'upper_type': {'bsonType': 'string',
#                'enum': ['stride',
#                 'splice',
#                 'casual',
#                 'formal',
#                 'jacket',
#                 'logo',
#                 'plaid',
#                 'thin_stripes',
#                 'tshirt',
#                 'other',
#                 'v_neck',
#                 'suit',
#                 'thick_stripes',
#                 'shirt',
#                 'sweater',
#                 'vest',
#                 'cotton',
#                 'suit_up',
#                 'tight'],
#                'description': 'Typeofupperbodyclothing'},
#               'footwear': {'bsonType': 'string',
#                'enum': ['leather',
#                 'sport',
#                 'boots',
#                 'cloth',
#                 'casual',
#                 'sandals',
#                 'stocking',
#                 'leather_shoes',
#                 'shoes',
#                 'sneaker'],
#                'description': 'Typeoffootwear'},
#               'carrying': {'bsonType': 'string',
#                'enum': ['hand_bag',
#                 'shoulder_bag',
#                 'hold_objects_in_front',
#                 'backpack',
#                 'messenger_bag',
#                 'nothing',
#                 'plastic_bags',
#                 'baby_buggy',
#                 'shopping_trolley',
#                 'umbrella',
#                 'folder',
#                 'luggage_case',
#                 'suitcase',
#                 'box',
#                 'plastic_bag',
#                 'paper_bag',
#                 'hand_trunk',
#                 'other'],
#                'description': 'Itemsbeingcarriedbytheperson'},
#               'lower_type': {'bsonType': 'string',
#                'enum': ['stripe',
#                 'pattern',
#                 'long_coat',
#                 'trousers',
#                 'shorts',
#                 'skirt_and_dress',
#                 'boots',
#                 'long_trousers',
#                 'skirt',
#                 'short_skirt',
#                 'dress',
#                 'jeans',
#                 'tight_trousers',
#                 'capri',
#                 'hot_pants',
#                 'long_skirt',
#                 'plaid',
#                 'thin_stripes',
#                 'suits',
#                 'casual',
#                 'formal'],
#                'description': 'Typeoflowerbodyclothing'},
#               'brand_name': {'bsonType': 'string',
#                'enum': ['tvs',
#                 'maruti_suzuki',
#                 'eicher',
#                 'ashok_leyland',
#                 'mercedes_benz',
#                 'royal_enfield',
#                 'chevrolet',
#                 'fiat',
#                 'jaguar',
#                 'audi',
#                 'toyota',
#                 'sml',
#                 'bajaj',
#                 'jbm',
#                 'bharat_benz',
#                 'hero_motor',
#                 'volvo',
#                 'nissan',
#                 'renault',
#                 'volkswagen',
#                 'mazda',
#                 'hero_honda',
#                 'hyundai',
#                 'mg',
#                 'skoda',
#                 'land_rover',
#                 'yamaha',
#                 'kia',
#                 'mahindra',
#                 'mitsubishi',
#                 'ford',
#                 'jeep',
#                 'tata_motors',
#                 'honda',
#                 'bmw',
#                 'coupe',
#                 'force'],
#                'description': 'Brandnameofthevehicle'},
#               'vehicle_color': {'bsonType': 'string',
#                'enum': ['khakhi',
#                 'silver',
#                 'yellow',
#                 'pink',
#                 'purple',
#                 'green',
#                 'blue',
#                 'brown',
#                 'maroon',
#                 'red',
#                 'orange',
#                 'violet',
#                 'white',
#                 'black',
#                 'grey'],
#                'description': 'Colorofthevehicle'},
#               'vehicle_i_type': {'bsonType': 'string',
#                'enum': ['hmv',
#                 'lmv',
#                 'lgv',
#                 '3_axle',
#                 '5_axle',
#                 'mcwg',
#                 '6_axle',
#                 '2_axle',
#                 '4_axle',
#                 'heavy_vehicle'],
#                'description': 'Vehicleclassificationtype'},
#               'vehicle_type': {'bsonType': 'string',
#                'enum': ['sedan',
#                 'suv',
#                 'micro',
#                 'hatchback',
#                 'wagon',
#                 'pick_up',
#                 'convertible'],
#                'description': 'Typeofvehicle'},
#               'special_type': {'bsonType': 'string',
#                'enum': ['army_vehicle',
#                 'ambulance',
#                 'graminseva_4wheeler',
#                 'graminseva_3wheeler',
#                 'campervan'],
#                'description': 'Specialvehicletype'}}},
#             'label': {'bsonType': 'string',
#              'enum': ['bus',
#               'car',
#               'truck',
#               'motorbike',
#               'bicycle',
#               'e_rikshaw',
#               'cycle_rikshaw',
#               'tractor',
#               'cement_mixer',
#               'mini_truck',
#               'mini_bus',
#               'mini_van',
#               'van'],
#              'description': 'Vehicletypewhattypeofvehicleisdetected'},
#             'score': {'bsonType': 'number',
#              'description': 'Confidencescoreforthedetection'},
#             'match_id': {'bsonType': 'string',
#              'description': 'MatchIDforpersonidentification'},
#             'severity': {'bsonType': 'string'},
#             'subclass': {'bsonType': 'string',
#              'description': 'Subclassforthedetectedobject'}}}},
#          'c_timestamp': {'bsonType': 'date',
#           'description': 'Timestampoftheevent'}}}}}}}}],
#  'version': 1}
